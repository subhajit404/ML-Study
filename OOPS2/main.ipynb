# %%
class Bag:
    def __init__(self,material,zip):
        self.material=material
        self.zip=zip
    def show(self):
        print(f"things inside is {self.material},{self.zip}")

rebok = Bag("Leather",3)
campus = Bag("Leather",2)
rebok.show()
campus.show()
# Out:
# things inside is Leather,3
# things inside is Leather,2

# %% [markdown]
# # **Method**

# %%
class Animal:
    def __init__(self,age):
        self.age=age
    def show(self): # instance method 
        print(f"The age is {self.age}")
    @classmethod
    def hello(cls):
        print(f"Hello Brother how are you{cls}")
    @staticmethod
    def bro():
        print("Hello Bro how are you")

dog = Animal(12)
dog.show()
dog.hello()
dog.bro()
# Out:
# The age is 12
# Hello Brother how are you<class '__main__.Animal'>
# Hello Bro how are you
