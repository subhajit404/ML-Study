# %%
try:
    n =int(input("enter the number :"))
    result = 10 /n
except Exception as ex:
    print(ex)
else:
    print("good there is no error ")
print(result)
# Out:
# good there is no error
# 5.0
