# %%
for i in range(1,11):
    for j in range(1,i+1):
        print(f"i is --> {i} and j is --> {j}")
# Out:
# i is --> 1 and j is --> 1
# i is --> 2 and j is --> 1
# i is --> 2 and j is --> 2
# i is --> 3 and j is --> 1
# i is --> 3 and j is --> 2
# i is --> 3 and j is --> 3
# i is --> 4 and j is --> 1
# i is --> 4 and j is --> 2
# i is --> 4 and j is --> 3
# i is --> 4 and j is --> 4
# i is --> 5 and j is --> 1
# i is --> 5 and j is --> 2
# i is --> 5 and j is --> 3
# i is --> 5 and j is --> 4
# i is --> 5 and j is --> 5
# i is --> 6 and j is --> 1
# i is --> 6 and j is --> 2
# i is --> 6 and j is --> 3
# i is --> 6 and j is --> 4
# i is --> 6 and j is --> 5
# i is --> 6 and j is --> 6
# i is --> 7 and j is --> 1
# i is --> 7 and j is --> 2
# i is --> 7 and j is --> 3
# i is --> 7 and j is --> 4
# i is --> 7 and j is --> 5
# i is --> 7 and j is --> 6
# i is --> 7 and j is --> 7
# i is --> 8 and j is --> 1
# i is --> 8 and j is --> 2
# i is --> 8 and j is --> 3
# i is --> 8 and j is --> 4
# i is --> 8 and j is --> 5
# i is --> 8 and j is --> 6
# i is --> 8 and j is --> 7
# ...
